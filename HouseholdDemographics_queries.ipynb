# %%
import psycopg2

# %%
conn = psycopg2.connect(
    dbname = 'dbretail',
    user = 'dsstudent', 
    password = 'GoBis0ns47#', 
    host = 'dbretailcampaign.cluster-cpkaamuwqi1l.us-east-2.rds.amazonaws.com', 
    port = '5432' 
)

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('postgresql+psycopg2://dsstudent:GoBis0ns47#@dbretailcampaign.cluster-cpkaamuwqi1l.us-east-2.rds.amazonaws.com:5432/dbretail')

# %%
sql_query = 'SELECT * FROM HouseholdDemographics WHERE HouseholdId BETWEEN 601 AND 800;'
df = pd.read_sql(sql_query, engine)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   householdid      67 non-null     int64
#  1   agegroup         67 non-null     object
#  2   maritalstatus    67 non-null     object
#  3   income           67 non-null     object
#  4   homeownerstatus  67 non-null     object
#  5   householddesc    67 non-null     object
#  6   householdsize    67 non-null     object
#  7   householdminors  67 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 4.3+ KB

# %%
df.describe(include = "all")
# Out:
#         householdid agegroup maritalstatus  income homeownerstatus  \
# count     67.000000       67            67      67              67
# unique          NaN        6             3      10               4
# top             NaN    45-54       Married  50-74K       Homeowner
# freq            NaN       23            36      19              45
# mean     704.910448      NaN           NaN     NaN             NaN
# std       58.875506      NaN           NaN     NaN             NaN
# min      601.000000      NaN           NaN     NaN             NaN
# 25%      665.500000      NaN           NaN     NaN             NaN
# 50%      708.000000      NaN           NaN     NaN             NaN
# 75%      754.000000      NaN           NaN     NaN             NaN
# max      800.000000      NaN           NaN     NaN             NaN
#
#         householddesc householdsize householdminors
# count              67            67              67
# unique              6             5               4
# top     2 Adults Kids             2    None/Unknown
# freq               21            26              41
# mean              NaN           NaN             NaN
# std               NaN           NaN             NaN
# min               NaN           NaN             NaN
# 25%               NaN           NaN             NaN
# 50%               NaN           NaN             NaN
# 75%               NaN           NaN             NaN
# max               NaN           NaN             NaN
