# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('postgresql+psycopg2://dsstudent:GoBis0ns47#@dbretailcampaign.cluster-cpkaamuwqi1l.us-east-2.rds.amazonaws.com:5432/dbretail')

# %%
sql_query = "SELECT COLUMN_NAME FROM INFORMATION_SCHEMA.COLUMNS WHERE TABLE_NAME = 'advertisementdata';"
df = pd.read_sql(sql_query, engine)
df
# Out:
#             column_name
# 0  advertisemententryid
# 1             productid
# 2               storeid
# 3               weeknum
# 4             displayid
# 5              mailerid

# %%
sql_query = "SELECT tds.householdid, ad.storeid, ad.weeknum, pd.productdesc, pd.productsubdesc, adat.displayadtypedesc " \
                " FROM transactiondata_subset tds " \
                "INNER JOIN products pd ON tds.productid = pd.productid " \
                "INNER JOIN advertisementdata ad ON tds.productid = ad.productid " \
                    "" \
                "INNER JOIN advertisementdisplayadtypes adat ON ad.displayid = adat.displayadid " \
                "WHERE tds.householdid BETWEEN 601 AND 800 ;"
df = pd.read_sql(sql_query, engine)
df

# %%
#sql_query3 = 'SELECT ad.storeid, pd.dept, pd.brand, pd.productdesc, pd.productsubdesc, adt.displayadtypedesc ' \
            #'FROM transactiondata_subset tds ' \
            #'INNER JOIN advertisementdata ad ON tds.productid = ad.productid ' \
            #'AND tds.storeid = ad.storeid ' \
            #'INNER JOIN products pd ON tds.productid = pd.productid' \
            #'INNER JOIN advertisementdisplayadtypes adt ON ad.displayid::int = adt.displayadid ' \
            #'WHERE tds.householdid BETWEEN 601 AND 800;'
#product_advert = pd.read_sql(sql_query3, engine)
#product_advert.describe(include = "all")

# %%
#new_sql_query = 'SELECT tds.householdid, ad.weeknum, pd.productdesc, pd.productsubdesc, ' \
            'ad.storeid, tds.daynum, tds.transactiontime, adt.displayadtypedesc ' \
            'FROM transactiondata_subset tds ' \
            'INNER JOIN advertisementdata ad ON tds.productid = ad.productid ' \
            'AND tds.weeknum = ad.weeknum ' \
            'AND tds.storeid = ad.storeid ' \
            'INNER JOIN products pd ON ad.productid = pd.productid ' \
            'INNER JOIN advertisementdisplayadtypes adt ON ad.displayid::int = adt.displayadid ' \
            'WHERE tds.householdid BETWEEN 601 AND 800;'

#advert_tran = pd.read_sql(sql_query2, engine)
#advert_tran.describe(include = "all")

# %%
# advertisementdata

#sql_query2 = 'SELECT hd.agegroup, hd.maritalstatus, hd.income, hd.homeownerstatus, td.weeknum, td.transactiontime, ' \
                '' \
                'WHERE tds.householdid BETWEEN 601 AND 800;'
#advert_tran = pd.read_sql(sql_query2, engine)
#advert_tran.describe(include = "all")
